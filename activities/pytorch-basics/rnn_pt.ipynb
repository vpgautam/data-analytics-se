# %% [markdown]
# ## Basic RNN
# The aim of this notebook is to be able to implement a basic RNN. The idea is to build upon the basic understanding of the RNN, GRU and LSTM.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import numpy as np

# %% [markdown]
# Implement a simple one layer, one neuron RNN. Initialize two weight matrices, `Wx` and `Wy` with the values from a normal distribution. `Wx` contains connection weights for the inputs of the current time step, while `Wy`
